# %%
import geopandas as gpd
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# pd.set_option('display.max_rows', None)
# pd.set_option("display.max_colwidth", 0)

# %%
tan=gpd.read_file("../..//Data/tza_admbnda_adm0_20181019/tza_admbnda_adm0_20181019.shp")

# %%
tan
# Out:
#                        ADM0_EN                          ADM0_SW ADM0_PCODE  \
# 0  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
#
#                                             geometry
# 0  MULTIPOLYGON (((40.37704 -10.28385, 40.37401 -...

# %%
tan.plot()

# %%
tan2=gpd.read_file("../..//Data/tza_admbndl_all_20181019/tza_admbndl_ALL_20181019.shp")
tan2.plot()
tan2
# Out:
#        ET_ID  Id    ET_Left  ET_Right ADM3_L ADM2_L ADM1_L ADM0_L  AdmLevel  \
# 0          0   0 -999999999       195   None   None   None   None        99
# 1          0   0 -999999999       196   None   None   None   None        99
# 2          0   0 -999999999       238   None   None   None   None        99
# 3          0   0 -999999999       242   None   None   None   None        99
# 4          0   0 -999999999       243   None   None   None   None        99
# ...      ...  ..        ...       ...    ...    ...    ...    ...       ...
# 13346      0   0 -999999999      2784   None   None   None   None         0
# 13347      0   0 -999999999       653   None   None   None   None         0
# 13348      0   0 -999999999      1437   None   None   None   None         0
# 13349      0   0 -999999999      1165   None   None   None   None         0
# 13350      0   0 -999999999      2049   None   None   None   None         0
#
#       ADM0_R ADM1_R  ADM2_R     ADM3_R  \
# 0         TZ   TZ02  TZ0201  TZ0201101
# 1         TZ   TZ02  TZ0201  TZ0201113
# 2         TZ   TZ02  TZ0204  TZ0204021
# 3         TZ   TZ02  TZ0204  TZ0204061
# 4         TZ   TZ02  TZ0204  TZ0204071
# ...      ...    ...     ...        ...
# 13346     TZ   TZ20  TZ2006  TZ2006081
# 13347     TZ   TZ04  TZ0408  TZ0408201
# 13348     TZ   TZ10  TZ1006  TZ1006031
# 13349     TZ   TZ09  TZ0901  TZ0901041
# 13350     TZ   TZ15  TZ1501  TZ1501011
#
#                                                 geometry
# 0      LINESTRING (35.87309 -3.62574, 35.87243 -3.623...
# 1      LINESTRING (35.86892 -3.42357, 35.86863 -3.423...
# 2      LINESTRING (35.81432 -3.44431, 35.81435 -3.444...
# 3      LINESTRING (34.78717 -3.79432, 34.78756 -3.794...
# 4      LINESTRING (35.24624 -3.60686, 35.24233 -3.595...
# ...                                                  ...
# 13346  LINESTRING (34.09377 -1.02695, 34.09392 -1.027...
# 13347  LINESTRING (39.18237 -4.65122, 39.18304 -4.651...
# 13348  LINESTRING (34.99621 -11.57281, 34.98964 -11.5...
# 13349  LINESTRING (40.41354 -10.49679, 40.41286 -10.4...
# 13350  LINESTRING (31.22436 -8.58863, 31.22279 -8.588...
#
# [13351 rows x 14 columns]

# %%
tan3=gpd.read_file("../..//Data/tza_admbnda_adm3_20181019/tza_admbnda_adm3_20181019.shp")
tan3.plot()
tan3
# Out:
#       ET_ID                      ADM0_EN                          ADM0_SW  \
# 0         0  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 1         1  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 2         2  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 3         3  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 4         4  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# ...     ...                          ...                              ...
# 3638   3638  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 3639   3639  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 3640   3640  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 3641   3641  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
# 3642   3642  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania
#
#      ADM0_PCODE ADM1_EN ADM1_PCODE       ADM2_EN ADM2_PCODE    ADM3_EN  \
# 0            TZ  Dodoma       TZ01        Kondoa     TZ0101    Bumbuta
# 1            TZ  Dodoma       TZ01        Kondoa     TZ0101       Pahi
# 2            TZ  Dodoma       TZ01        Kondoa     TZ0101      Haubi
# 3            TZ  Dodoma       TZ01        Kondoa     TZ0101    Kalamba
# 4            TZ  Dodoma       TZ01        Kondoa     TZ0101    Kwadelo
# ...         ...     ...        ...           ...        ...        ...
# 3638         TZ    Mara       TZ20  Musoma Urban     TZ2005  Nyamatare
# 3639         TZ    Mara       TZ20  Musoma Urban     TZ2005   Mwisenge
# 3640         TZ    Mara       TZ20  Musoma Urban     TZ2005     Buhare
# 3641         TZ    Mara       TZ20  Musoma Urban     TZ2005     Makoko
# 3642         TZ   Pwani       TZ06      Bagamoyo     TZ0601     Mbwewe
#
#      ADM3_PCODE                                           geometry
# 0     TZ0101011  POLYGON ((35.93715 -4.59737, 35.93632 -4.59956...
# 1     TZ0101021  POLYGON ((35.93456 -4.61214, 35.93301 -4.61637...
# 2     TZ0101041  POLYGON ((35.92014 -4.74797, 35.92617 -4.74806...
# 3     TZ0101051  POLYGON ((35.88398 -4.78581, 35.88743 -4.78581...
# 4     TZ0101061  POLYGON ((36.33663 -4.84585, 36.33696 -4.84824...
# ...         ...                                                ...
# 3638  TZ2005102  POLYGON ((33.79640 -1.50518, 33.79659 -1.50546...
# 3639  TZ2005112  POLYGON ((33.79930 -1.49437, 33.79839 -1.49619...
# 3640  TZ2005122  POLYGON ((33.78340 -1.50927, 33.78362 -1.50937...
# 3641  TZ2005132  POLYGON ((33.74137 -1.48448, 33.74225 -1.48497...
# 3642  TZ0601153  POLYGON ((38.29781 -5.97371, 38.29781 -5.97456...
#
# [3643 rows x 11 columns]

# %%
tan4=gpd.read_file("../..//Data/tza_admbnda_adm2_20181019/tza_admbnda_adm2_20181019.shp")
tan4.plot()
tan4
# Out:
#                          ADM0_EN                          ADM0_SW ADM0_PCODE  \
# 0    United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 1    United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 2    United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 3    United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 4    United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# ..                           ...                              ...        ...
# 165  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 166  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 167  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 168  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
# 169  United Republic of Tanzania  Jamhuri ya Muungano wa Tanzania         TZ
#
#     ADM1_EN ADM1_PCODE       ADM2_EN ADM2_PCODE  \
# 0    Arusha       TZ02        Arusha     TZ0206
# 1    Arusha       TZ02  Arusha Urban     TZ0203
# 2    Arusha       TZ02        Karatu     TZ0204
# 3    Arusha       TZ02       Longido     TZ0207
# 4    Arusha       TZ02          Meru     TZ0202
# ..      ...        ...           ...        ...
# 165   Tanga       TZ04       Lushoto     TZ0401
# 166   Tanga       TZ04        Mkinga     TZ0408
# 167   Tanga       TZ04        Muheza     TZ0403
# 168   Tanga       TZ04       Pangani     TZ0405
# 169   Tanga       TZ04   Tanga Urban     TZ0404
#
#                                               geometry
# 0    MULTIPOLYGON (((36.82231 -3.44251, 36.82211 -3...
# 1    POLYGON ((36.63247 -3.36366, 36.63215 -3.36382...
# 2    POLYGON ((35.89154 -3.25459, 35.88634 -3.26033...
# 3    MULTIPOLYGON (((36.35742 -3.05734, 36.35728 -3...
# 4    POLYGON ((36.89951 -3.05109, 36.90068 -3.05144...
# ..                                                 ...
# 165  POLYGON ((38.40366 -4.10869, 38.40923 -4.11184...
# 166  POLYGON ((39.19192 -4.65801, 39.19538 -4.66106...
# 167  POLYGON ((38.67176 -4.93219, 38.67882 -4.93282...
# 168  POLYGON ((38.87129 -5.26710, 38.87237 -5.26745...
# 169  POLYGON ((39.03636 -4.96072, 39.03665 -4.96094...
#
# [170 rows x 8 columns]

# %%
tan5=gpd.read_file("../..//Data/2012_ward_shapefiles/2012 Wards Shapefiles/TZwards.shp")
tan5.plot()
tan5
# Out:
#      Region_Cod Region_Nam District_C        District_N Ward_Code   Ward_Name  \
# 0            01     Dodoma         01            Kondoa       011     Bumbuta
# 1            01     Dodoma         01            Kondoa       021        Pahi
# 2            01     Dodoma         01            Kondoa       041       Haubi
# 3            01     Dodoma         01            Kondoa       051     Kalamba
# 4            01     Dodoma         01            Kondoa       061     Kwadelo
# ...         ...        ...        ...               ...       ...         ...
# 3639         20       Mara         05  Musoma Municipal       092  Kamunyonge
# 3640         20       Mara         05  Musoma Municipal       102   Nyamatare
# 3641         20       Mara         05  Musoma Municipal       112    Mwisenge
# 3642         20       Mara         05  Musoma Municipal       122      Buhare
# 3643         20       Mara         05  Musoma Municipal       132      Makoko
#
#           Division  SHAPE_Leng  SHAPE_Area  \
# 0             None    0.769320    0.015383
# 1             None    0.450216    0.008900
# 2             None    0.538672    0.012175
# 3             None    0.678941    0.023225
# 4             None    0.721114    0.025358
# ...            ...         ...         ...
# 3639  Musoma Mjini    0.044213    0.000088
# 3640  Musoma Mjini    0.034092    0.000069
# 3641  Musoma Mjini    0.064565    0.000208
# 3642  Musoma Mjini    0.134753    0.000802
# 3643  Musoma Mjini    0.169222    0.001070
#
#                                                geometry
# 0     POLYGON ((35.93715 -4.59737, 35.93632 -4.59956...
# 1     POLYGON ((35.93456 -4.61214, 35.93301 -4.61637...
# 2     POLYGON ((35.92014 -4.74797, 35.92617 -4.74806...
# 3     POLYGON ((35.88398 -4.78581, 35.88743 -4.78581...
# 4     POLYGON ((36.33663 -4.84585, 36.33696 -4.84824...
# ...                                                 ...
# 3639  POLYGON ((33.80214 -1.49403, 33.80300 -1.49524...
# 3640  POLYGON ((33.79640 -1.50518, 33.79659 -1.50546...
# 3641  POLYGON ((33.79930 -1.49437, 33.79839 -1.49619...
# 3642  POLYGON ((33.78340 -1.50927, 33.78362 -1.50937...
# 3643  POLYGON ((33.74137 -1.48448, 33.74225 -1.48497...
#
# [3644 rows x 10 columns]

# %%
tan6=gpd.read_file("../../Data/2012_ward_shapefiles/2012 Wards Shapefiles/Waterbodies.shp")
tan6.plot()
tan6
# Out:
#    DISTRICT  AREA  PERIMETER  TZ_05G_ REGION  WARD Status  \
# 0      None   0.0        0.0      0.0   None  None   None
# 1      None   0.0        0.0      0.0   None  None   None
# 2      None   0.0        0.0      0.0   None  None   None
# 3      None   0.0        0.0      0.0   None  None   None
# 4      None   0.0        0.0      0.0   None  None   None
# 5      None   0.0        0.0      0.0   None  None   None
# 6      None   0.0        0.0      0.0   None  None   None
# 7      None   0.0        0.0      0.0   None  None   None
# 8      None   0.0        0.0      0.0   None  None   None
# 9      None   0.0        0.0      0.0   None  None   None
# 10     None   0.0        0.0      0.0   None  None   None
# 11     None   0.0        0.0      0.0   None  None   None
# 12     None   0.0        0.0      0.0   None  None   None
# 13     None   0.0        0.0      0.0   None  None   None
# 14     None   0.0        0.0      0.0   None  None   None
# 15     None   0.0        0.0      0.0   None  None   None
# 16     None   0.0        0.0      0.0   None  None   None
# 17     None   0.0        0.0      0.0   None  None   None
# 18     None   0.0        0.0      0.0   None  None   None
#
#                   LAKES  Shape_Leng  Shape_Area  \
# 0          Indian Ocean   59.894583   18.682106
# 1             Lake Jipe    0.268544    0.002323
# 2   Nyumba ya Mungu DAM    0.461220    0.002880
# 3           Lake Natron    1.398117    0.063938
# 4                  None    3.867540    0.060025
# 5          Lake Manyara    0.974515    0.035433
# 6            Lake Eyasi    2.154606    0.089168
# 7           Lake  Nyasa    7.558174    0.854277
# 8       Lake Tanganyika   17.357347    2.643376
# 9            Lake Rukwa    4.581139    0.413219
# 10                 None    0.481897    0.002026
# 11          Lake Sagara    0.742820    0.009178
# 12        Lake Victoria   33.216360    2.820744
# 13                 None    0.078357    0.000359
# 14          Lake Ikimba    0.251173    0.002928
# 15                 None    0.260172    0.002429
# 16                 None    0.323753    0.004373
# 17                 None    0.222577    0.002033
# 18                 None    0.494122    0.002766
#
#                                              geometry
# 0   MULTIPOLYGON (((41.51959 -1.86923, 41.49802 -1...
# 1   POLYGON ((37.73992 -3.52891, 37.74040 -3.52972...
# 2   POLYGON ((37.46104 -3.58468, 37.46177 -3.58468...
# 3   MULTIPOLYGON (((35.94130 -2.06934, 35.95540 -2...
# 4   MULTIPOLYGON (((30.56722 -1.33471, 30.56933 -1...
# 5   POLYGON ((35.85693 -3.42383, 35.86052 -3.42477...
# 6   POLYGON ((35.30147 -3.37953, 35.31045 -3.38805...
# 7   POLYGON ((34.02574 -9.50013, 34.03432 -9.50585...
# 8   POLYGON ((29.28001 -3.36555, 29.29070 -3.36743...
# 9   POLYGON ((31.80027 -7.42260, 31.80200 -7.42444...
# 10  POLYGON ((30.81962 -1.41026, 30.82051 -1.41038...
# 11  POLYGON ((31.22803 -5.21786, 31.23312 -5.22003...
# 12  MULTIPOLYGON (((34.02949 -0.99794, 34.03165 -1...
# 13  POLYGON ((37.69421 -3.32104, 37.69199 -3.32174...
# 14  POLYGON ((31.58056 -1.43213, 31.58125 -1.43276...
# 15  POLYGON ((35.19497 -4.66612, 35.18945 -4.66513...
# 16  POLYGON ((35.40987 -4.28610, 35.42346 -4.29271...
# 17  POLYGON ((35.89106 -3.88251, 35.88635 -3.88417...
# 18  MULTIPOLYGON (((34.39042 -4.02205, 34.39007 -4...

# %%
tan7=gpd.read_file("../../Data/data/TAN_boundaries.shp")
tan7.plot()
tan7
# Out:
#       ID  LEFT  RIGHT  LEVEL  \
# 0      0    41     40      1
# 1      1    -1     41      0
# 2      2    43     40      1
# 3      3    -1     40      0
# 4      4    -1    159      0
# ..   ...   ...    ...    ...
# 368  368    -1     70      0
# 369  369    -1     71      0
# 370  370    -1    100      0
# 371  371    -1    101      0
# 372  372    -1    102      0
#
#                                               geometry
# 0    LINESTRING (30.36444 -3.77422, 30.36577 -3.775...
# 1    LINESTRING (30.36444 -3.77422, 30.37284 -3.771...
# 2    LINESTRING (30.94211 -4.94815, 30.75382 -4.947...
# 3    LINESTRING (29.72802 -4.45687, 29.73800 -4.462...
# 4    LINESTRING (39.09507 -5.18791, 39.09495 -5.188...
# ..                                                 ...
# 368  LINESTRING (39.52833 -9.06131, 39.52413 -9.058...
# 369  LINESTRING (39.57632 -9.10012, 39.57305 -9.097...
# 370  LINESTRING (40.34564 -10.26475, 40.34024 -10.2...
# 371  LINESTRING (40.37530 -10.28676, 40.37133 -10.2...
# 372  LINESTRING (40.42349 -10.38134, 40.42162 -10.3...
#
# [373 rows x 5 columns]

# %%
tan8=gpd.read_file("../../Data/data (1)/TZA_adm2.shp")
tan8.plot()
tan8
# Out:
#      ID_0  ISO    NAME_0  ID_1                      NAME_1  ID_2  \
# 0     227  TZA  Tanzania     1                      Arusha     1
# 1     227  TZA  Tanzania     1                      Arusha     2
# 2     227  TZA  Tanzania     1                      Arusha     3
# 3     227  TZA  Tanzania     1                      Arusha     4
# 4     227  TZA  Tanzania     1                      Arusha     5
# ..    ...  ...       ...   ...                         ...   ...
# 178   227  TZA  Tanzania    28              Zanzibar North   179
# 179   227  TZA  Tanzania    29  Zanzibar South and Central   180
# 180   227  TZA  Tanzania    29  Zanzibar South and Central   181
# 181   227  TZA  Tanzania    30               Zanzibar West   182
# 182   227  TZA  Tanzania    30               Zanzibar West   183
#
#             NAME_2    HASC_2  CCN_2 CCA_2      TYPE_2   ENGTYPE_2 NL_NAME_2  \
# 0     Arusha Urban      None      0    03      Wilaya    District      None
# 1           Arusha  TZ.AS.AS      0    06      Wilaya    District      None
# 2           Karatu  TZ.AS.KA      0    04      Wilaya    District      None
# 3       Lake Eyasi      None      0  None  Water body  Water body      None
# 4     Lake Manyara      None      0  None  Water body  Water body      None
# ..             ...       ...    ...   ...         ...         ...       ...
# 178  Kaskazini 'B'  TZ.ZN.NB      0    02      Wilaya    District      None
# 179           Kati  TZ.ZS.CE      0    01      Wilaya    District      None
# 180         Kusini  TZ.ZS.SO      0    02      Wilaya    District      None
# 181      Magharibi  TZ.ZW.WE      0    01      Wilaya    District      None
# 182          Mjini  TZ.ZW.TO      0    02      Wilaya    District      None
#
#                                              VARNAME_2  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 178  Kaskazini B|North B|Zansibar North|Zanzibar No...
# 179                                   Zanzibar Central
# 180                                     Zanzibar South
# 181                                      Zanzibar West
# 182                                      Zanzibar Town
#
#                                               geometry
# 0    POLYGON ((36.63328 -3.36609, 36.63297 -3.36625...
# 1    MULTIPOLYGON (((36.79362 -3.39325, 36.79359 -3...
# 2    POLYGON ((35.89234 -3.25703, 35.88714 -3.26276...
# 3    POLYGON ((35.17556 -3.46569, 35.17746 -3.46491...
# 4    POLYGON ((35.77901 -3.56244, 35.77862 -3.56134...
# ..                                                 ...
# 178  MULTIPOLYGON (((39.20542 -5.91153, 39.20542 -5...
# 179  MULTIPOLYGON (((39.49653 -6.12236, 39.49653 -6...
# 180  POLYGON ((39.53042 -6.17796, 39.53042 -6.17875...
# 181  MULTIPOLYGON (((39.33430 -6.41708, 39.33430 -6...
# 182  POLYGON ((39.21404 -6.14200, 39.21427 -6.14206...
#
# [183 rows x 15 columns]

# %%
tan4=gpd.read_file("../..//Data/tanzania-adm1-adm2-uscb-dec16/Tanzania_adm1_uscb_2016.shp")
tan4.plot()
tan9
# Out:
#                     AREA_NAME                           GEO_MATCH  \
# 0                      ARUSHA                     TANZANIA_ARUSHA
# 1                       COAST                      TANZANIA_COAST
# 2               DAR ES SALAAM              TANZANIA_DAR ES SALAAM
# 3                      DODOMA                     TANZANIA_DODOMA
# 4                       GEITA                      TANZANIA_GEITA
# 5                      IRINGA                     TANZANIA_IRINGA
# 6                      KAGERA                     TANZANIA_KAGERA
# 7                      KATAVI                     TANZANIA_KATAVI
# 8                      KIGOMA                     TANZANIA_KIGOMA
# 9                 KILIMANJARO                TANZANIA_KILIMANJARO
# 10  NYUMBA YA MUNGU RESERVIOR  TANZANIA_NYUMBA YA MUNGU RESERVIOR
# 11               LAKE MANYARA               TANZANIA_LAKE MANYARA
# 12                 LAKE EYASI                 TANZANIA_LAKE EYASI
# 13                LAKE NATRON                TANZANIA_LAKE NATRON
# 14                 LAKE RUKWA                 TANZANIA_LAKE RUKWA
# 15              LAKE VICTORIA              TANZANIA_LAKE VICTORIA
# 16                      LINDI                      TANZANIA_LINDI
# 17                    MANYARA                    TANZANIA_MANYARA
# 18                       MARA                       TANZANIA_MARA
# 19                      MBEYA                      TANZANIA_MBEYA
# 20                   MOROGORO                   TANZANIA_MOROGORO
# 21                     MTWARA                     TANZANIA_MTWARA
# 22                     MWANZA                     TANZANIA_MWANZA
# 23                     NJOMBE                     TANZANIA_NJOMBE
# 24                PEMBA NORTH                TANZANIA_PEMBA NORTH
# 25                PEMBA SOUTH                TANZANIA_PEMBA SOUTH
# 26                      RUKWA                      TANZANIA_RUKWA
# 27                     RUVUMA                     TANZANIA_RUVUMA
# 28                  SHINYANGA                  TANZANIA_SHINYANGA
# 29                     SIMIYU                     TANZANIA_SIMIYU
# 30                    SINGIDA                    TANZANIA_SINGIDA
# 31                     TABORA                     TANZANIA_TABORA
# 32                      TANGA                      TANZANIA_TANGA
# 33     ZANZIBAR CENTRAL/SOUTH     TANZANIA_ZANZIBAR CENTRAL/SOUTH
# 34             ZANZIBAR NORTH             TANZANIA_ZANZIBAR NORTH
# 35        ZANZIBAR URBAN/WEST        TANZANIA_ZANZIBAR URBAN/WEST
#
#                                              geometry
# 0   POLYGON ((35.37493 -1.75253, 35.38629 -1.75894...
# 1   MULTIPOLYGON (((39.32537 -8.29182, 39.32573 -8...
# 2   POLYGON ((39.12353 -6.56599, 39.12413 -6.56608...
# 3   MULTIPOLYGON (((35.20107 -6.46152, 35.20087 -6...
# 4   MULTIPOLYGON (((31.81681 -2.69948, 31.81538 -2...
# 5   POLYGON ((34.93465 -6.88894, 34.93741 -6.88941...
# 6   MULTIPOLYGON (((31.69659 -2.27978, 31.69388 -2...
# 7   POLYGON ((30.71316 -5.16723, 30.71344 -5.17008...
# 8   MULTIPOLYGON (((31.46043 -4.45760, 31.46122 -4...
# 9   POLYGON ((37.27535 -2.85506, 37.28927 -2.85816...
# 10  POLYGON ((37.52092 -3.53513, 37.52087 -3.53926...
# 11  POLYGON ((35.82732 -3.43810, 35.82910 -3.43910...
# 12  POLYGON ((35.30594 -3.38382, 35.30600 -3.38384...
# 13  POLYGON ((36.02073 -2.58451, 36.01609 -2.58676...
# 14  POLYGON ((31.77360 -7.66708, 31.98710 -7.77408...
# 15  POLYGON ((31.83361 -0.99929, 31.85308 -1.00000...
# 16  MULTIPOLYGON (((39.52993 -9.05018, 39.52988 -9...
# 17  MULTIPOLYGON (((37.20211 -3.45259, 37.20285 -3...
# 18  MULTIPOLYGON (((33.33204 -2.28312, 33.33268 -2...
# 19  POLYGON ((33.03025 -6.86766, 33.03483 -6.86880...
# 20  POLYGON ((37.46150 -5.80199, 37.46317 -5.80270...
# 21  MULTIPOLYGON (((40.37703 -10.28388, 40.37400 -...
# 22  MULTIPOLYGON (((32.88346 -2.80786, 32.88171 -2...
# 23  POLYGON ((34.70531 -8.66320, 34.70781 -8.66449...
# 24  MULTIPOLYGON (((39.68011 -5.13726, 39.67963 -5...
# 25  MULTIPOLYGON (((39.65907 -5.45179, 39.65935 -5...
# 26  POLYGON ((31.00048 -7.11500, 31.00305 -7.11530...
# 27  POLYGON ((35.91607 -9.31472, 35.91781 -9.31744...
# 28  POLYGON ((32.51190 -3.19621, 32.51291 -3.19731...
# 29  POLYGON ((33.91067 -2.17989, 33.91653 -2.18071...
# 30  POLYGON ((34.75051 -3.81299, 34.75007 -3.83696...
# 31  MULTIPOLYGON (((32.67514 -4.10150, 32.67513 -4...
# 32  POLYGON ((38.56061 -4.21994, 38.57523 -4.23018...
# 33  POLYGON ((39.39929 -6.02157, 39.39951 -6.02161...
# 34  MULTIPOLYGON (((39.38455 -5.82218, 39.38389 -5...
# 35  POLYGON ((39.28132 -6.03706, 39.28188 -6.03844...

# %%
crs = {'init': 'epsg:4326'} #coordinate system based on lat/long
geometry = [Point(xy) for xy in zip(data['longitude'],data['latitude'])]
geo_df = gpd.GeoDataFrame(data,
                          crs = crs,
                          geometry=geometry)
geo_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3816ea286726> in <module>
#       1 crs = {'init': 'epsg:4326'} #coordinate system based on lat/long
# ----> 2 geometry = [Point(xy) for xy in zip(data['longitude'],data['latitude'])]
#       3 geo_df = gpd.GeoDataFrame(data,
#       4                           crs = crs,
#       5                           geometry=geometry)
#
# NameError: name 'data' is not defined

# %%
gdf = gpd.GeoDataFrame(
    tan10, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e3acf3021dcc> in <module>
#       1 gdf = gpd.GeoDataFrame(
# ----> 2     tan10, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
#
# NameError: name 'df' is not defined

# %%
tan10=gpd.read_file("../..//Data/tanzania-adm1-adm2-uscb-dec16/Tanzania_adm2_uscb_2016.shp")
tan10.plot()
tan10
# Out:
#                      AREA_NAME                               GEO_MATCH  \
# 0    NYUMBA YA MUNGU RESERVIOR      TANZANIA_NYUMBA YA MUNGU RESERVIOR
# 1                 LAKE MANYARA                   TANZANIA_LAKE MANYARA
# 2                   LAKE EYASI                     TANZANIA_LAKE EYASI
# 3                  LAKE NATRON                    TANZANIA_LAKE NATRON
# 4                   LAKE RUKWA                     TANZANIA_LAKE RUKWA
# ..                         ...                                     ...
# 170                     KUSINI  TANZANIA_ZANZIBAR CENTRAL/SOUTH_KUSINI
# 171                KASKAZINI A     TANZANIA_ZANZIBAR NORTH_KASKAZINI A
# 172                KASKAZINI B     TANZANIA_ZANZIBAR NORTH_KASKAZINI B
# 173                  MAGHARIBI  TANZANIA_ZANZIBAR URBAN/WEST_MAGHARIBI
# 174                      MJINI      TANZANIA_ZANZIBAR URBAN/WEST_MJINI
#
#                                               geometry
# 0    POLYGON ((37.52092 -3.53513, 37.52087 -3.53926...
# 1    POLYGON ((35.82732 -3.43810, 35.82910 -3.43910...
# 2    POLYGON ((35.30594 -3.38382, 35.30600 -3.38384...
# 3    POLYGON ((36.02073 -2.58451, 36.01609 -2.58676...
# 4    POLYGON ((31.77360 -7.66708, 31.98710 -7.77408...
# ..                                                 ...
# 170  POLYGON ((39.52930 -6.17602, 39.52933 -6.17619...
# 171  MULTIPOLYGON (((39.38455 -5.82218, 39.38389 -5...
# 172  POLYGON ((39.22642 -5.89249, 39.22653 -5.89266...
# 173  POLYGON ((39.27509 -6.02771, 39.27877 -6.02799...
# 174  POLYGON ((39.21118 -6.13794, 39.21146 -6.13815...
#
# [175 rows x 3 columns]

# %%
#import shape file into geopandas
TZ = gpd.read_file('../data/GIS_Maps/Regions.shp')
#TZ.to_csv('Tanzania_shapes.csv')
5:07
#add coordinate geometry to dataframe and save as csv
crs = {'init': 'epsg:4326'} #coordinate system based on lat/long
geometry = [Point(xy) for xy in zip(data['longitude'],data['latitude'])]
geo_df = gpd.GeoDataFrame(data,
                          crs = crs,
                          geometry=geometry)
geo_df.head()
#geo_df.to_csv('geo_data.csv')
5:07
#function to define X,y coordinates from points
def getPointCoords(row, geom, coord_type):
    if coord_type == 'x':
        return row[geom].x
    elif coord_type == 'y':
        return row[geom].y
5:07
# Calculate x coordinates
geo_df['x'] = geo_df.apply(getPointCoords, geom='geometry', coord_type='x', axis=1)
# Calculate y coordinates
geo_df['y'] = geo_df.apply(getPointCoords, geom='geometry', coord_type='y', axis=1)
# Let's see what we have now
geo_df.head()

#drop row with 0.0 as X coord
out = geo_df['x'] != 0.0
bok_df = geo_df[out]
bok_df.to_csv('geodata_clean.csv') #save file for later use
bok_df.head()

(I also use Bokeh, but not for that map - it is still a geo dataframe)

#plot by status_group (not using bokeh, yet!)
fig,ax = plt.subplots(figsize=(20,15))
TZ.plot(ax=ax, alpha = .25, cmap = 'Purples')
bok_df[bok_df['status_group']== 'functional'].plot(ax = ax, markersize = 3, alpha=.5,
                                                  color='blue', marker = 'o',label = 'Functional');
bok_df[bok_df['status_group']== 'functional needs repair'].plot(ax=ax,markersize=3,alpha=.5,
                                                                color='red', marker = 'o',label = 'Repair Needed')
bok_df[bok_df['status_group']== 'non functional'].plot(ax=ax,markersize=3,alpha=.25,
                                                      color='grey',marker='o',label = 'Non Functional')
ax.axis('off')
plt.legend(loc='upper right', fontsize='18',markerscale=10);
# Out:
#   File "<ipython-input-14-bbfc09509e04>", line 4
#     5:07
#        ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
