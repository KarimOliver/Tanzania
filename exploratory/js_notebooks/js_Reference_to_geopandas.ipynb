# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
kc=gpd.read_file('../../../../Mod 1/mod-1-project-chicago-seattle-ds-051120/src/data/shapefiles/kingcounty/king00blk.shp')
kc
# Out:
#       STATEFP00 COUNTYFP00 TRACTCE00 BLOCKCE00        BLKIDFP00      NAME00  \
# 0            53        033    032209      1014  530330322091014  Block 1014
# 1            53        033    032210      1015  530330322101015  Block 1015
# 2            53        033    032209      3005  530330322093005  Block 3005
# 3            53        033    032103      2022  530330321032022  Block 2022
# 4            53        033    032212      2006  530330322122006  Block 2006
# ...         ...        ...       ...       ...              ...         ...
# 24470        53        033    030202      2011  530330302022011  Block 2011
# 24471        53        033    030100      4000  530330301004000  Block 4000
# 24472        53        033    030100      1004  530330301001004  Block 1004
# 24473        53        033    030100      4005  530330301004005  Block 4005
# 24474        53        033    030305      2001  530330303052001  Block 2001
#
# ...

# %%
kc.plot(cmap= 'jet',figsize= (10,10))
kc
# Out:
#       STATEFP00 COUNTYFP00 TRACTCE00 BLOCKCE00        BLKIDFP00      NAME00  \
# 0            53        033    032209      1014  530330322091014  Block 1014
# 1            53        033    032210      1015  530330322101015  Block 1015
# 2            53        033    032209      3005  530330322093005  Block 3005
# 3            53        033    032103      2022  530330321032022  Block 2022
# 4            53        033    032212      2006  530330322122006  Block 2006
# ...         ...        ...       ...       ...              ...         ...
# 24470        53        033    030202      2011  530330302022011  Block 2011
# 24471        53        033    030100      4000  530330301004000  Block 4000
# 24472        53        033    030100      1004  530330301001004  Block 1004
# 24473        53        033    030100      4005  530330301004005  Block 4005
# 24474        53        033    030305      2001  530330303052001  Block 2001
#
# ...

# %%
skc=kc[kc["NAME00"].str.match("1")== True]
skc.plot(figsize=(10,10))

# %%
kc.head()
# Out:
#   STATEFP00 COUNTYFP00 TRACTCE00 BLOCKCE00        BLKIDFP00      NAME00  \
# 0        53        033    032209      1014  530330322091014  Block 1014
# 1        53        033    032210      1015  530330322101015  Block 1015
# 2        53        033    032209      3005  530330322093005  Block 3005
# 3        53        033    032103      2022  530330321032022  Block 2022
# 4        53        033    032212      2006  530330322122006  Block 2006
#
#   MTFCC00 UR00 UACE00 FUNCSTAT00  ALAND00  AWATER00   INTPTLAT00  \
# 0   G5040    U  80389          S    57549         0  +47.5999603
# 1   G5040    R   None          S    13509         0  +47.5590646
# 2   G5040    U  80389          S    43083         0  +47.6305372
# 3   G5040    U  80389          S   100631         0  +47.5274475
# 4   G5040    U  80389          S     8792         0  +47.5749251
#
#      INTPTLON00                                           geometry
# 0  -122.0180131  POLYGON ((1347762.970 221430.739, 1347761.905 ...
# ...

# %%
gp=gpd.read_file('../../src/data/shapefiles/block2000/block2000.shp')
gp.plot(figsize= (10,10))
gp.info
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../../src/data/shapefiles/block2000/block2000.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-7-5a7c19d6898d> in <module>
# ----> 1 gp=gpd.read_file('../../src/data/shapefiles/block2000/block2000.shp')
#       2 gp.plot(figsize= (10,10))
#       3 gp.info
#
# ~\anaconda3\envs\Tanzania\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
# ...

# %%
tp=gpd.read_file('../../src/data/shapefiles/king00bg/king00bg.shp')
tp.plot(figsize= (10,10))
tp.info()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../../src/data/shapefiles/king00bg/king00bg.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-8-684f9ffc8789> in <module>
# ----> 1 tp=gpd.read_file('../../src/data/shapefiles/king00bg/king00bg.shp')
#       2 tp.plot(figsize= (10,10))
#       3 tp.info()
#
# ~\anaconda3\envs\Tanzania\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
# ...

# %%
bp=gpd.read_file('../../src/data/shapefiles/king00blk_0/king00blk.shp')
bp.plot(figsize= (10,10));
bp.info
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../../src/data/shapefiles/king00blk_0/king00blk.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-9-4aa69d3797d8> in <module>
# ----> 1 bp=gpd.read_file('../../src/data/shapefiles/king00blk_0/king00blk.shp')
#       2 bp.plot(figsize= (10,10));
#       3 bp.info
#
# ~\anaconda3\envs\Tanzania\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
# ...

# %%
lp=gpd.read_file('../../src/data/shapefiles/king10bg/king10bg.shp')
lp.plot(figsize= (10,10));
lp.head()
# Out:
#   STATEFP10 COUNTYFP10 TRACTCE10 BLKGRPCE10       GEOID10     NAMELSAD10  \
# 0        53        033    031800          3  530330318003  Block Group 3
# 1        53        033    032002          2  530330320022  Block Group 2
# 2        53        033    032003          4  530330320034  Block Group 4
# 3        53        033    032003          2  530330320032  Block Group 2
# 4        53        033    032003          1  530330320031  Block Group 1
#
#   MTFCC10 FUNCSTAT10   ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 0   G5030          S   7721649    366603  +47.4033807  -122.0977634
# 1   G5030          S  14273551    189028  +47.4408675  -122.0138338
# 2   G5030          S  98885738    304929  +47.4347167  -121.8853379
# 3   G5030          S   8754787         0  +47.4141677  -121.9912620
# 4   G5030          S   6487558         0  +47.3964042  -122.0257171
#
#                                             geometry
# 0  POLYGON ((1327897.748 143740.928, 1327565.901 ...
# ...

# %%
skc=lp[lp["BLKGRPCE10"].str.match("^7")== True]
skc.plot(figsize=(10,10));

# %%
hp=gpd.read_file('../../src/data/shapefiles/reg00puma_0/reg00puma.shp')
hp.plot(figsize= (10,10))
hp
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../../src/data/shapefiles/reg00puma_0/reg00puma.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-128-b150ffb724a5> in <module>
# ----> 1 hp=gpd.read_file('../../src/data/shapefiles/reg00puma_0/reg00puma.shp')
#       2 hp.plot(figsize= (10,10))
#       3 hp
#
# ~\anaconda3\envs\oy-env\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
# ...

# %%
dp=gpd.read_file('../../src/data/shapefiles/reg10puma_0/reg10puma.shp')
dp.plot(figsize= (10,10))
dp

# %%
kc_puma_codes = ['11613', '11614', '11615','11616','11606','11607','11608','11609','11610','11611','11612','11605','11604','11603','11602','11601']
kc = dp[dp['PUMACE10'].isin(kc_puma_codes)]


kc.plot(figsize= (10,10));
kc.info()

# %%
skc_puma_codes = ['11613', '11614', '11615', '11612']
skc = kc[kc['PUMACE10'].isin(skc_puma_codes)]
skc.plot(facecolor= 'red',figsize= (10,10));

# %%
bg=kc.plot(ax=ax), skc.plot(ax=ax, facecolor='red');

# %%
fig, ax = plt.subplots(1,1,figsize =(100,100))
kc.plot(ax=ax)
ax.set_axis_off()
#plt.title('Southern King County',)
skc.plot(ax=ax, facecolor='red');

# %%
choros=kc[(kc.POP10>0)]
choros['Population_Density']=choros.POP10/sum(tp.ACRES)*100

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax = plt.subplots(1,1, figsize= (10,10))
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="10%", pad=0.1)
#plt.title('Poulation Density per Acre', loc= 'top')
ax.set_axis_off()
choros.plot(column='Population_Density',cmap= 'jet', ax=ax,legend=True,cax=cax, legend_kwds={'label': "Population Density per Acre",'orientation': "horizontal"});

# %%
choro.Population_d

# %%
choros.POP10
